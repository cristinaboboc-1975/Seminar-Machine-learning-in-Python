# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cristinaboboc-1975/Seminar-Machine-learning-in-Python/blob/main/LP1_Machine_Learning_in_Python_NOU.ipynb)

# %% [markdown]
# # Laborator 1 — Bazele limbajului Python pentru Machine Learning
#
# **Curs:** Machine Learning in Python · Laborator asociat Cursului 1 (Introducere în Machine Learning)
#
# ### Ce vei învăța în acest laborator
# - Expresii, tipuri de date (numere, text) și operatori în Python
# - Variabile, atribuiri și denumirea corectă a acestora
# - Comparații și valori booleene
# - Apelarea funcțiilor și a funcțiilor din librării (`math`, `operator`)
# - Vectori (`numpy`), liste și indexare
# - Crearea și manipularea tabelelor de date cu `pandas` (DataFrame)
# - Citirea unui fișier CSV real și o primă curățare a datelor
#
# > 💡 **Recomandare:** nu doar citi celulele — rulează-le, modifică-le și experimentează. Exersarea activă este esențială pentru a înțelege sintaxa Python.

# %%
# Când deschideți acest notebook, rulați mai întâi celula de mai jos pentru a importa
# librăriile de bază de care veți avea nevoie pe tot parcursul laboratorului.

# Librării de bază
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Expresii

# %% [markdown]
# ### Noțiuni preliminare
#
# Despre limbajul de programare Python:
# - este popular atât pentru *data science*, cât și pentru dezvoltarea de aplicații software;
# - stăpânirea noțiunilor de bază ale limbajului este extrem de importantă;
# - sintaxa de bază este ușor de înțeles;
# - este esențială **exersarea** metodelor și procedurilor — nu doar citirea codului sau ascultarea explicațiilor.

# %%
3 * 4

# %%
3 * 4 + 5 * 3

# %% [markdown]
# Expresiile în Python respectă aceleași reguli de precedență ca în algebră: înmulțirea și împărțirea au prioritate față de adunare și scădere. Parantezele pot fi folosite pentru a grupa expresii mai mici într-o expresie mai mare.

# %%
# Parantezele sunt folosite pentru a grupa subexpresiile
3 * (4 + 5) * 3

# %%
2 ** 5   # ridicare la putere: 2 la puterea 5

# %% [markdown]
# ⚠️ **Atenție la sintaxă.** Limbajele de programare sunt foarte pretențioase în privința sintaxei — un singur spațiu sau simbol greșit produce o eroare. Celula de mai jos conține **intenționat** o eroare de sintaxă (`* *` în loc de `**`), pentru a vedea cum arată un mesaj de eroare în Python.

# %%
# Această celulă va genera o eroare (SyntaxError) — este intenționat!
2 * * 5

# %% [markdown]
# ## 2. Tipuri de date: numere

# %% [markdown]
# Numerele întregi se numesc valori **int** în Python. Ele reprezintă doar numere întregi (negative, zero sau pozitive), fără componentă fracționară.
#
# Numerele reale se numesc valori **float** (*floating point*). Ele pot reprezenta atât numere întregi, cât și fracționare, dar au unele limitări:
# - au o dimensiune limitată (deși limita este foarte mare);
# - au o precizie limitată la aproximativ 15 cifre semnificative.

# %%
# Împărțire (rezultatul este întotdeauna float)
9 / 2

# %%
# Tipul rezultatului
type(9 / 2)

# %%
# Împărțirea întreagă (câtul împărțirii)
9 // 2

# %%
# Ce tip are rezultatul împărțirii întregi?
type(9 // 2)

# %%
int(4.5)   # trunchiază partea zecimală

# %%
int('4.5')   # ❗ nu funcționează direct pe un șir cu zecimale — vom vedea eroarea

# %% [markdown]
# ## 3. Atribuiri și nume

# %% [markdown]
# - Instrucțiunile nu au o valoare; ele efectuează o acțiune.
# - O instrucțiune de **atribuire** schimbă semnificația numelui din stânga simbolului `=`.
# - Numele este legat de o **valoare** (nu de o formulă/ecuație — valoarea se calculează o singură dată, în momentul atribuirii).

# %%
num_1 = 5
num_2 = 20
# rezultatul înmulțirii, fără a-l atribui unei variabile
num_1 * num_2

# %%
# atribuirea rezultatului unei variabile
total = num_1 * num_2

# %%
print(total)

# %%
print(total * 2)

# %% [markdown]
# O serie de linii de cod, într-o singură celulă sau în celule succesive, permite construirea unui calcul complex în etape, dând nume rezultatelor intermediare — la fel ca mai jos.

# %%
total   # variabila 'total' rămâne disponibilă în celulele următoare

# %%
salariu_zilnic = 524
salariu_lunar = 20 * salariu_zilnic
numar_zile_lucratoare_an = 252
salariu_anual = numar_zile_lucratoare_an * salariu_zilnic
salariu_anual

# %% [markdown]
# ### 📝 Exercițiu
#
# Atribuiți variabilei `numar_secunde_deceniu` numărul de secunde dintre miezul nopții de la 1 ianuarie 2010 și miezul nopții de la 1 ianuarie 2020 (un deceniu întreg, cu 2 ani bisecți: 2012 și 2016).

# %%
# Soluție — încearcă mai întâi singur/singură, apoi compară cu varianta de mai jos!
nr_ani_bisecti = 2
nr_secunde_minut = 60
nr_secunde_ora = nr_secunde_minut * 60
nr_secunde_zi = nr_secunde_ora * 24

numar_secunde_deceniu = (nr_ani_bisecti * nr_secunde_zi * 366
                          + 8 * nr_secunde_zi * 365)

numar_secunde_deceniu

# %% [markdown]
# ## 4. Tipuri de date: text și șiruri de caractere

# %% [markdown]
# Un șir de caractere (**string**) este o porțiune de text de orice lungime:
#
# - `'a'`
# - `'cuvânt'`
# - `"Noi suntem studenți!"`
#
# Șirurile de caractere care conțin numere pot fi convertite în numere:
# - `int('12')`
# - `float('1.2')`
#
# Orice valoare poate fi convertită într-un șir de caractere folosind `str(...)`, de exemplu `str(5)`.

# %%
str(5)

# %%
"Master " + "data" + " " + "science"   # concatenare de șiruri cu +

# %%
# Atribuim variabile de tip text
d = "data"
s = "science"
spatiu = " "

# %%
d

# %%
# Folosim valorile din celula anterioară
d + spatiu + s

# %%
str(2 ** 5)

# %%
suta = 100
print("Am " + str(suta) + " lei")   # 'str()' este necesar pentru a concatena un număr cu text

# %%
datasci = "data science"
polsci = datasci.replace("data", "political")
print(polsci)

# %% [markdown]
# ### 📝 Exercițiu — erori de tip (type errors)
#
# Rulați, pe rând, fiecare dintre următoarele expresii, folosind:
#
# ```python
# x = 3
# y = '4'
# z = '5.6'
# ```
#
# - `x + y`
# - `x + int(y + z)`
# - `str(x) + int(y)`
# - `str(x, y) + z`
#
# Pentru fiecare, identificați **de ce** apare eroarea (sau, dacă nu apare, ce rezultat se obține).

# %%
x = 3
y = '4'
z = '5.6'

x + y   # ❗ TypeError: nu poți aduna direct un int (x) cu un str (y)

# %% [markdown]
# **Explicații:**
#
# - `x + y` → **eroare**: `x` este `int`, `y` este `str`; Python nu adună automat tipuri diferite.
# - `x + int(y + z)` → **eroare**: `y + z` concatenează șirurile la `'45.6'`, iar `int('45.6')` eșuează pentru că șirul conține un punct zecimal (`int()` nu acceptă zecimale).
# - `str(x) + int(y)` → **eroare**: `str(x)` este `'3'` (text), iar `int(y)` este `4` (număr); nu poți concatena text cu un număr folosind `+`.
# - `str(x, y) + z` → **eroare**: `str()` nu acceptă doi parametri de acest fel — sintaxa este greșită.
#
# Încearcă variantele corecte, de exemplu: `str(x) + y` sau `x + int(y)`.

# %% [markdown]
# ## 5. Comparații și relații booleene

# %%
3 > 1 + 10

# %%
# Comparație înlănțuită — echivalentă cu (1 > 1+1) and (1+1 < 3)
1 > 1 + 1 < 3

# %%
x = 12
y = 50.0

# La ce se referă această operație? (indiciu: comparație înlănțuită)
min(x, y) <= (x + y) / 2 > max(x, y)

# %%
# Comparații ale unor șiruri de caractere, în ordine alfabetică
"Dog" > "Catastrophe" > "Horse"

# %%
# Literele mari sunt "mai mici" decât literele mici, în codificarea ASCII/Unicode
"D" < "d"

# %% [markdown]
# ## 6. Apelarea unei funcții

# %% [markdown]
# Apelarea unei funcții este numită și **operație**. Numele funcției apare primul, urmat de argumente scrise între paranteze.

# %%
abs(-12)

# %%
round(5 - 1.3)

# %%
max(6, 4)

# %%
max(6, 4, 3 + 4)

# %%
# help() afișează documentația unei funcții
help(max)

# %%
import math
import operator

print(math.ceil(3.2))
print(math.pi)
print(operator.pow(2, 5))
print(operator.add(2, 5))

# %% [markdown]
# ## 7. Vectori, șiruri, tupluri și liste

# %% [markdown]
# Un **array** (vector, din `numpy`) conține o secvență de valori:
#
# - toate elementele unui vector au, de regulă, același tip;
# - operațiile aritmetice se aplică individual fiecărui element;
# - când doi vectori sunt adunați, trebuie să aibă aceeași dimensiune — elementele corespunzătoare se adună între ele;
# - o coloană dintr-un set de date este, în esență, un vector.
#
# Un **range** (șir) este un vector de numere consecutive:
# - `np.arange(end)` — generează numerele de la 0 până la `end - 1`.

# %%
# crearea unui vector folosind funcția numpy arange
my_array = np.arange(2, 8)
my_array

# %%
# crearea unei liste — folosind paranteze pătrate
# spre deosebire de vectori, listele pot conține valori de tipuri diferite
my_list = [1, 2, 3, 4]
my_list

# %%
my_list1 = [1, 2, 3, 4, 'c']
my_list1

# %%
print(sum(my_array))
print(my_array.sum())

# %% [markdown]
# ⚠️ Următoarea celulă va genera o eroare: `sum()` nu poate aduna elemente de tipuri diferite (numere și text) dintr-o listă.

# %%
print(sum(my_list1))   # ❗ TypeError

# %%
print(sum(my_list))   # aici funcționează, toate elementele sunt numere

# %%
# adunarea a doi vectori — elementele corespunzătoare se adună
# (cei doi vectori trebuie să aibă aceeași dimensiune!)
my_array1 = np.arange(5, 11)
print(my_array1)
my_array + my_array1

# %%
print(my_array.size)
print(len(my_array))

# %%
np.count_nonzero([1, 2, 0, 2, 1, 0, 2])   # numără elementele diferite de 0

# %%
print(np.arange(10))

# %%
print(np.arange(5, 10, 2))   # start, stop, pas

# %%
venituri = np.array([500, 210, 300])
cheltuieli = np.array([400, 200, 280])
economii = venituri - cheltuieli
print("Economiile sunt " + str(economii))

# %%
rata_economisire = economii / venituri
print("Rata de economisire este: " + str(np.round(rata_economisire, 2)))

# %% [markdown]
# ## 8. Extragerea elementelor dintr-un vector (indexare)

# %%
my_array3 = np.arange(101, 119)
# primul element din șir (indexarea începe de la 0!)
my_array3[0]

# %%
my_array3[1:7]   # elementele de la poziția 1 până la 6 (poziția 7 e exclusă)

# %%
# Care va fi rezultatul acestei expresii? Încearcă să prezici înainte de a rula.
my_array3[12:3:-2]   # start, stop, pas negativ (mergem invers)

# %%
# Comanda split desparte un șir de caractere într-o listă de șiruri, după un separator dat
mystring1 = 'this is a long and dull exercise'
mystring1.split(' ')

# %%
# Selectarea unui singur element din lista rezultată din split
mystring1.split(' ')[1]

# %% [markdown]
# ### 📝 Exercițiu
#
# Folosind comanda `split`, tăierea listei (*slicing*) și concatenarea șirurilor cu `+`, obțineți din șirul `'learning is done by machine'` rezultatul `'machine learning'`.

# %%
# Soluție — încearcă mai întâi singur/singură!
mach1 = 'learning is done by machine'
cuvinte = mach1.split(' ')       # ['learning', 'is', 'done', 'by', 'machine']
mach2 = cuvinte[-1] + ' ' + cuvinte[0]   # 'machine' + ' ' + 'learning'
mach2

# %% [markdown]
# ## 9. Crearea de tabele — DataFrame

# %%
# DataFrame() gol
pd.DataFrame()

# %%
pd.DataFrame({'Number of petals': [8, 34, 5]})

# %%
# un DataFrame cu 2 coloane
pd.DataFrame({'Number of petals': [8, 34, 5],
              'Name': ['Lotus', 'Sunflower', 'Rose']})

# %%
matrix = pd.DataFrame({'col1': [0, 4],
                        'col2': [1, 5],
                        'col3': [2, 6],
                        'col4': [3, 7]})
matrix

# %%
matrix.T   # transpusa tabelului (rânduri <-> coloane)

# %%
flowers = pd.DataFrame({'Number of petals': [8, 34, 5],
                         'Name': ['Lotus', 'Sunflower', 'Rose']})
flowers

# %%
# adăugarea unei coloane noi
flowers = pd.DataFrame({'Number of petals': [8, 34, 5], 'Name': ['Lotus', 'Sunflower', 'Rose']})
flowers['Color'] = ['pink', 'yellow', 'red']
flowers

# %%
flowers.shape   # (număr de rânduri, număr de coloane)

# %%
# numărul de linii și numărul de coloane, separat
print(flowers.shape[0])
print(flowers.shape[1])
flowers

# %%
flowers.columns.values   # numele coloanelor

# %% [markdown]
# ## 10. Citirea unui tabel de date într-un DataFrame

# %% [markdown]
# Tabelul `galton.csv` oferă date bazate pe faimosul studiu din 1885 al lui **Francis Galton**, care explorează relația dintre înălțimea copiilor adulți și înălțimea părinților lor. Fiecare caz este un copil adult, iar variabilele sunt:
#
# - **family** — familia căreia îi aparține copilul, etichetată de la 1 la 205;
# - **father** — înălțimea tatălui, în inci;
# - **mother** — înălțimea mamei, în inci;
# - **gender** — sexul copilului, bărbat (`male`) sau femeie (`female`);
# - **childHeight** — înălțimea copilului.

# %% [markdown]
# **Încărcarea datelor** — celula de mai jos funcționează direct, oriunde ai rula notebook-ul (local, Jupyter, Colab), fără să fie nevoie de Google Drive: dacă ai deja fișierul `galton.csv` în același folder cu notebook-ul, îl citește de acolo; altfel îl descarcă automat de pe un depozit public (GitHub) și îl salvează local pentru rulările următoare.

# %%
import os

CSV_LOCAL = "galton.csv"
CSV_URL = "https://raw.githubusercontent.com/data-8/materials-fa17/master/lec/galton.csv"

if os.path.exists(CSV_LOCAL):
    galton_df = pd.read_csv(CSV_LOCAL)
else:
    galton_df = pd.read_csv(CSV_URL)
    galton_df.to_csv(CSV_LOCAL, index=False)   # salvăm local, pentru rulările următoare

galton_df.head()

# %% [markdown]
# > 💡 **Notă pentru Google Colab:** dacă preferați să încărcați fișierul din propriul Google Drive (de exemplu, alt set de date pentru un proiect), puteți folosi codul de mai jos — **nu este necesar pentru `galton.csv`**, care se descarcă automat mai sus.
# >
# > ```python
# > from google.colab import drive
# > drive.mount('/content/drive')
# > galton_df = pd.read_csv("/content/drive/MyDrive/<folderul_tau>/galton.csv")
# > ```

# %%
galton_df.shape

# %%
# selectarea primelor 8 rânduri — un mod de a extrage un subset de rânduri
galton_df.head(8)

# %%
print('Coloanele și tipul datelor din Python:')
[(x, type(galton_df[x][0])) for x in galton_df.columns]

# %%
galton_df.describe(include='all').T

# %% [markdown]
# ## 11. Utilizarea DataFrame-urilor (Table)

# %%
# extragerea unei coloane
galton_df['gender'][0:10]

# %%
# un alt mod de a extrage o coloană (funcționează doar dacă numele nu conține spații)
galton_df.gender

# %%
type(galton_df[['gender', 'family']])

# %%
# folosirea comenzii drop pentru a elimina o coloană nedorită
galton_df.drop(['children'], axis=1).head(10)

# %%
new_df = galton_df[galton_df.midparentHeight > 75]

# %%
new_df

# %%
# dacă vrem să selectăm anumite RÂNDURI, avem mai multe opțiuni
# iloc folosește poziția din tabel
galton_df.iloc[3:5]

# %%
# extragerea observațiilor care verifică o anumită condiție (OR — cel puțin una din condiții)
galton_df[(galton_df.gender == 'female') | (galton_df.children == 4)]

# %%
# extragerea observațiilor care verifică ambele condiții simultan (AND)
galton_df[(galton_df.gender == 'female') & (galton_df.children == 4)]

# %%
# selectarea aleatoare a 5 rânduri
galton_df.sample(5)

# %% [markdown]
# ## 12. O primă curățare a datelor

# %% [markdown]
# Curățarea datelor este un pas important într-un proiect de machine learning — îl vom relua în detaliu în Cursurile 2 și 3.

# %%
# pentru fiecare coloană, numărăm valorile existente (nenule), ca să vedem
# cât de multe valori lipsă există în baza de date
galton_df.count()

# %%
# înlăturarea coloanelor cu multe valori lipsă, sau păstrarea doar a coloanelor de interes
# în cazul nostru, păstrăm doar 3 coloane
galton3_df = galton_df[['father', 'mother', 'childHeight']]

# comanda pentru înlăturarea rândurilor cu valori lipsă (NaN)
galton3_df = galton3_df.dropna()
galton3_df.count()

# %% [markdown]
# ## Recapitulare
#
# În acest laborator ai exersat:
# - ✅ expresii, precedența operatorilor și tipurile de date de bază (`int`, `float`, `str`)
# - ✅ atribuiri de variabile și denumirea corectă a acestora
# - ✅ comparații și valori booleene
# - ✅ apelarea funcțiilor, inclusiv din librăriile `math` și `operator`
# - ✅ vectori (`numpy`) și liste — creare, operații, indexare
# - ✅ tabele de date (`pandas` DataFrame) — creare, citire dintr-un CSV, selecție de rânduri/coloane
# - ✅ o primă curățare a datelor (identificarea și eliminarea valorilor lipsă)
#
# ➡️ **Următorul laborator (LP 2)** continuă cu înțelegerea și pregătirea datelor: calitatea datelor, vizualizare, detectarea outlierilor și teste de normalitate — în pregătirea pentru primele modele de Machine Learning.
